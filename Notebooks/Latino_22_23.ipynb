# %%
# Se importan las librerías necesarias.
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# Uso de API's
import requests

# Importar librerías para procesamiento de texto
import re

# Se declara el ID del cliente.
client_id = 'dfff11bd971645718dc18ad43117de2b'
 
# Se declara el valor del secret client.
client_secret = '5c52326b7fc84a3bb8fc8d36b939c6a3'
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
 
# Se crea el cliente que se utilizará para consumir la API.
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Se busca información sobre latino/2022 - Bucle para buscar las 500 canciones

dicc_latino_22 = {"Artista": [], "Album": [], "Cancion": [], "Año Lanzamiento": [], "Total tracks": []}

contador = 0

while contador < 500:
    for valor in range(0,451,50):
        result_latino_total_22 = sp.search(q='genre: latino year: 2022', type='track', limit=50, offset={valor})

        for elemento in result_latino_total_22['tracks']['items']:
            dicc_latino_22["Artista"].append(elemento['artists'][0]['name'])
            dicc_latino_22["Album"].append(elemento['album']['name'])
            dicc_latino_22["Cancion"].append(elemento['name'])
            dicc_latino_22["Año Lanzamiento"].append(elemento['album']['release_date'])
            dicc_latino_22["Total tracks"].append(elemento['album']['total_tracks'])
            contador += 1

print (dicc_latino_22)
# Out:
# {'Artista': ['Bad Bunny', 'Bad Bunny', 'Feid', 'Shakira', 'Ozuna', 'Rauw Alejandro', 'Becky G', 'Luis Fonsi', 'Gente De Zona', 'Chuwi', 'Mima', 'Gente De Zona', 'Chuwi', 'Ozuna', 'Gente De Zona', 'Ozuna', 'Chuwi', 'Nacho', 'Mitú', 'Ozuna', 'Isabella Lovestory', 'Ozuna', 'Mima', 'Mima', 'Danny Ocean', 'Ozuna', 'Luna Luna', 'Danny Ocean', 'KAROL G', 'Sofía Reyes', 'Mima', 'Los Inconformes', 'Bebo Dumont', 'Bad Gyal', 'Young Miko', '2024 Hottest Songs', 'Von Galo', 'SOG', 'Mima', 'Piso 21', 'Mima', 'Mula', 'Jarina De Marco', 'Calma Carmona', 'Beéle', 'Black Guayaba', 'Chuwi', 'Mima', 'PIQUETE', 'Cardi B', 'Mima', 'ÌFÉ', 'Yandel', 'Bacilos', 'LA GENTE SF', 'Belinda', 'Yng Lvcas', 'Mint Field', 'Von Galo', 'Mario Bautista', 'Elena Rose', 'LAGOS', 'Bang Data', 'Mitú', 'Marc Seguí', 'DannyLux', 'Mint Field', 'Zion & Lennox', 'Quevedo', 'iZaak', 'J Balvin', 'La Misa Negra', 'Lp Certified', 'Kali Uchis', 'Meridian Brothers', 'Similar', 'Bad Bondy', 'Tiago PZK', 'Tayko', 'BluNites', 'Mint Field', 'Candy Colors', 'ÌFÉ', 'Mayani Swave', 'Siete Catorce', 'Ozomatli', 'Mint Field', 'De La Ghetto', 'Mint Field', 'Feid', 'Sebastian Yatra', 'Émina', 'Mint Field', 'LA GENTE SF', 'Mima', 'Feid', 'Bacilos', 'Nicole Zignago', 'El Hijo de Borikén', 'Calma Carmona', 'Okan', 'Puya', 'Similar', 'Dogos', 'Ozomatli', 'Mint Field', 'Sávila', 'Ozomatli', 'Tayko', 'BluNites', 'Puya', 'HYRA', 'Mint Field', '¿Téo?', 'Davila 666', 'ÌFÉ', 'Mayani Swave', 'Sebimor', '
# %%
# Transformar el diccionario de Latino/2022 en un Dataframe

df_latino_22 = pd.DataFrame(dicc_latino_22)

# %%
# Print del dataframe

df_latino_22
# Out:
#                     Artista  \
# 0                 Bad Bunny
# 1                 Bad Bunny
# 2                      Feid
# 3                   Shakira
# 4                     Ozuna
# ..                      ...
# 495                    Tavú
# 496          Kings of Salsa
# 497           Omaraga the G
# 498              The Marías
# 499  Elegante & La Imperial
#
#                                                  Album              Cancion  \
# 0                             EL ÚLTIMO TOUR DEL MUNDO               DÁKITI
# 1                                               DÁKITI               DÁKITI
# 2                                           CLASSY 101           CLASSY 101
# 3                                            Monotonía            Monotonía
# 4                                               Nibiru    Baila Baila Baila
# ..                                                 ...                  ...
# 495                                               Tavu  Recogiendo Impulsos
# 496  Top 40 Latin - The 30 Best Latin Hits of All Time             Baila Me
# 497                                   Naciones Latinas             Alvorada
# 498                            Top Tracks 100 Hot Hits       Run Your Mouth
# 499                                          Evolucion             Piensalo
#
#     Año Lanzamiento  Total tracks
# 0        2020-11-27            16
# 1        2020-10-30             1
# 2        2023-03-31             1
# 3        2022-10-19             1
# 4        2019-11-29            18
# ..              ...           ...
# 495      2004-01-01             9
# 496      2013-04-29            30
# 497      2024-09-22            60
# 498      2024-08-03           100
# 499      2018-05-14            10
#
# [500 rows x 5 columns]

# %%
# Se busca información sobre latino/2023 - Bucle para buscar las 500 canciones

dicc_latino_23 = {"Artista": [], "Album": [], "Cancion": [], "Año Lanzamiento": [], "Total tracks": []}

contador = 0

while contador < 500:
    for valor in range(0,451,50):
        result_latino_total = sp.search(q='genre: latino year: 2023', type='track', limit=50, offset={valor})

        for elemento in result_latino_total['tracks']['items']:
            dicc_latino_23["Artista"].append(elemento['artists'][0]['name'])
            dicc_latino_23["Album"].append(elemento['album']['name'])
            dicc_latino_23["Cancion"].append(elemento['name'])
            dicc_latino_23["Año Lanzamiento"].append(elemento['album']['release_date'])
            dicc_latino_23["Total tracks"].append(elemento['album']['total_tracks'])
            contador += 1

print (dicc_latino_23)
# Out:
# {'Artista': ['Bad Bunny', 'Myke Towers', 'Rauw Alejandro', 'Marshmello', 'HUMBE', 'Kali Uchis', 'Alvaro Diaz', 'Ela Minus', 'Shakira', 'Goth Babe', 'Kali Uchis', 'Becky G', 'J Balvin', 'HUMBE', 'iZaak', 'J Balvin', 'Alvaro Diaz', 'Becky G', 'Feid', '¿Téo?', 'Feid', 'Luna Luna', 'Kali Uchis', 'Shakira', 'Elsa y Elmar', 'Fusion Latina', 'Myke Towers', 'Chuwi', 'Mima', 'Marshmello', 'HYRA', 'Gente De Zona', 'Gizmo Varillas', 'Brytiago', 'Mayani Swave', 'Ozuna', 'Elsa y El
í', 'Milos', 'Turista', 'MaryOla', 'KAROL G', 'Ela Taubert', 'Katrina', 'La Mejor Música Electrónica', 'JHAYCO', 'Calibre 50', 'MOÜGLI', 'Twin Seas', 'Kali Uchis', 'RATAS', 'Tayko', 'Jarina De Marco', 'Tan Cologne', 'KAROL G', 'Danny Ocean', 'Adriel Favela', 'J Balvin', 'Giorgio Siladi', 'Renee Goust', 'El Otro Polo', 'Bad Gyal', 'unÁnima', 'Regal86', 'RATAS', 'Kaida', 'Words Four Two', 'Nolune', 'Omaraga the G', 'KAROL G', 'J Balvin', 'Lú Polanco', 'J Balvin', 'Feid', 'Mementut', 'Becky G', 'Paraísos', 'SCAIRAT', 'Omaraga the G', 'Sebastian Yatra', 'J Balvin', 'Nancy Sanchez', 'francia', 'Omaraga the G', 'The Marías', 'Sofía Reyes', 'Latin Electronic Dance Music', 'The Lsdays', 'Omaraga the G', 'Quevedo', 'Feid', 'Omaraga the G', 'Gaston Lopez', 'Danny Ocean', 'Tropiezo', 'Anitta', 'Mexican Institute Of Sound', 'Nhii', 'La Mejor Música Electrónica', 'Myke Towers', 'Elena Rose', 'J Balvin', 'JHAYCO', 'sailawway', 'Omaraga the G', 'Kenya Grace', 'Brray', 'Ela Taubert', 'Mexican Restaurant', 'Llane', 'DJ Sukha', 'Lú Polanco', 'Feid', 'Cheo', 'Myke Towers', 'Danny Ocean', 'Piso 21', 'Marc Seguí', 'Juanes', 'unÁnima', 'Feid', 'Zion & Lennox', 'Omaraga the G', 'Danny Ocean', 'La Mejor Música Electrónica', 'Maluma', 'Abraham Do ...

# %%
# Transformar el diccionario de Latino/2023 en un Dataframe

df_latino_23 = pd.DataFrame(dicc_latino_23)

# %%
# Print del dataframe

df_latino_23
# Out:
#             Artista                                    Album      Cancion  \
# 0         Bad Bunny      nadie sabe lo que va a pasar mañana  PERRO NEGRO
# 1       Myke Towers                           LA VIDA ES UNA         LALA
# 2    Rauw Alejandro                            PLAYA SATURNO      DILUVIO
# 3        Marshmello                               Sugar Papi  El Merengue
# 4             HUMBE                                 KINTSUGI     KINTSUGI
# ..              ...                                      ...          ...
# 495            Feid                     Hits 2023: Reggaetón  Niña Bonita
# 496        Jerry Di                        Latin Summer 2024    Mi Cuarto
# 497         KAROL G  Descubriendo Reggaeton Y Perreo Moderno          TQG
# 498     Sofía Reyes                      Latin Reggaeton Pop         Luna
# 499       Micro TDH                        Mega Hits Latinos   NEGRO MATE
#
#     Año Lanzamiento  Total tracks
# 0        2023-10-13            22
# 1        2023-03-23            23
# 2        2023-07-07            14
# 3        2023-11-03            11
# 4        2024-09-26             1
# ..              ...           ...
# 495      2023-11-10            25
# 496      2024-04-29            30
# 497      2024-07-02            32
# 498      2024-06-12            48
# 499      2024-01-30            30
#
# [500 rows x 5 columns]

# %%
# Unir los dos dataframes que tenemos (de 2022 y 2023). Utilizamos el ignore_index para crear un nuevo index con las 1000 canciones

dataframe_latino = pd.concat([df_latino_22, df_latino_23], ignore_index =True)

# %%
dataframe_latino
# Out:
#          Artista                                    Album            Cancion  \
# 0      Bad Bunny                 EL ÚLTIMO TOUR DEL MUNDO             DÁKITI
# 1      Bad Bunny                                   DÁKITI             DÁKITI
# 2           Feid                               CLASSY 101         CLASSY 101
# 3        Shakira                                Monotonía          Monotonía
# 4          Ozuna                                   Nibiru  Baila Baila Baila
# ..           ...                                      ...                ...
# 995         Feid                     Hits 2023: Reggaetón        Niña Bonita
# 996     Jerry Di                        Latin Summer 2024          Mi Cuarto
# 997      KAROL G  Descubriendo Reggaeton Y Perreo Moderno                TQG
# 998  Sofía Reyes                      Latin Reggaeton Pop               Luna
# 999    Micro TDH                        Mega Hits Latinos         NEGRO MATE
#
#     Año Lanzamiento  Total tracks
# 0        2020-11-27            16
# 1        2020-10-30             1
# 2        2023-03-31             1
# 3        2022-10-19             1
# 4        2019-11-29            18
# ..              ...           ...
# 995      2023-11-10            25
# 996      2024-04-29            30
# 997      2024-07-02            32
# 998      2024-06-12            48
# 999      2024-01-30            30
#
# [1000 rows x 5 columns]

# %%
# Guardar este DataFrame total como CSV

dataframe_latino.to_csv('dataframe_latino.csv')

# %%
#Una lista con todos los artirtas, sin repetir, que tenemos en este genero.

artistas_latino_total = list(dataframe_latino["Artista"].unique())

artistas_latino_total
# Out:
# ['Bad Bunny',
#  'Feid',
#  'Shakira',
#  'Ozuna',
#  'Rauw Alejandro',
#  'Becky G',
#  'Luis Fonsi',
#  'Gente De Zona',
#  'Chuwi',
#  'Mima',
#  'Nacho',
#  'Mitú',
#  'Isabella Lovestory',
#  'Danny Ocean',
#  'Luna Luna',
#  'KAROL G',
#  'Sofía Reyes',
#  'Los Inconformes',
#  'Bebo Dumont',
#  'Bad Gyal',
#  'Young Miko',
#  '2024 Hottest Songs',
#  'Von Galo',
#  'SOG',
#  'Piso 21',
#  'Mula',
#  'Jarina De Marco',
#  'Calma Carmona',
#  'Beéle',
#  'Black Guayaba',
#  'PIQUETE',
#  'Cardi B',
#  'ÌFÉ',
#  'Yandel',
#  'Bacilos',
#  'LA GENTE SF',
#  'Belinda',
#  'Yng Lvcas',
#  'Mint Field',
#  'Mario Bautista',
#  'Elena Rose',
#  'LAGOS',
#  'Bang Data',
#  'Marc Seguí',
#  'DannyLux',
#  'Zion & Lennox',
#  'Quevedo',
#  'iZaak',
#  'J Balvin',
#  'La Misa Negra',
#  'Lp Certified',
#  'Kali Uchis',
#  'Meridian Brothers',
#  'Similar',
#  'Bad Bondy',
#  'Tiago PZK',
#  'Tayko',
#  'BluNites',
#  'Candy Colors',
#  'Mayani Swave',
#  'Siete Catorce',
#  'Ozomatli',
#  'De La Ghetto',
#  'Sebastian Yatra',
#  'Émina',
#  'Nicole Zignago',
#  'El Hijo de Borikén',
#  'Okan',
#  'Puya',
#  'Dogos',
#  'Sávila',
#  'HYRA',
#  '¿Téo?',
#  'Davila 666',
#  'Sebimor',
#  'Roberto Fonseca',
#  'Yongolailan',
#  'Fofé Y Los Fetiches',
#  'Chango Menas',
#  'Zuaraz',
#  'Skapulario',
#  'Balún',
#  'Nutopia',
#  'Prettiest Eyes',
#  'Alegría Rampante',
#  'Vivanativa',
#  'Monttenegro',
#  'SAN CHA',
#  'Circo',
#  'GALE',
#  'Pachyman',
#  'Polaris',
#  'Milos',
#  'Rubytates',
#  'Seba Otero',
#  'Cabra',
#  'Gina Chavez',
#  'Ley Vara',
#  'NIKOLA',
#  'Adri Torron',
#  'RATAS',
#  'JAVVI ELIAS',
#  'B-Side Players',
#  'Polbo',
#  'La Dame Blanche',
#  'Words Four Two',
#  'Sofía Stainer',
#  'Qiensave',
#  'Laura Guevara',
#  'Red Tiger',
#  'La R',
#  'Ocho Ojos',
#  'Onda Moderna',
#  'Paraísos',
#  'Labajura',
#  'Breezewood la Connecta',
#  'TIMØ',
#  'Campo-Formio',
#  'Chris Jedi',
#  'Tainy',
#  'Blessd',
#  'Alex Sensation',
#  'Indigo',
#  'The Spam Allstars',
#  'La Mejor Música Electrónica',
#  'Boricua Boys',
#  'Omaraga the G',
#  'Un.real',
#  'The Flashers Brothers',
#  'JHAYCO',
#  'NY Latino Chillout Café',
#  'Tropiezo',
#  'Lú Polanco',
#  'MICHELLE',
#  'Como Las Movies',
#  'La Muchacha',
#  'Former Astronauts',
#  'SLVG',
#  'Yibáro',
#  'Poolpo',
#  'Kumbia Queers',
#  'Spam Allstars',
#  'Cabas',
#  'Turista',
#  'Moncho Berry',
#  'TROPA',
#  'Musica Latina',
#  'Salsaloco De Cuba',
#  'Sano',
#  'Bosques',
#  'Badshah',
#  'DJ Sukha',
#  'Alibi Music',
#  'Fusion Latina',
#  'Daddy Yankee',
#  'RAVEN DAVE',
#  'Aliss',
#  'Tito "El Bambino"',
#  'Anti-Sociales',
#  'Juventud Crasa',
#  'Bairoa',
#  'Musica Romantica de Fondo',
#  'UNRB',
#  'Signature Tracks',
#  'Anitta',
#  'Lalo Ebratt',
#  'Frontera Bugalú',
#  'Juanes',
#  'Myke Towers',
#  'Ovy On The Drums',
#  'Reik',
#  'AlterLatina',
#  'Musica Latina Playlist',
#  'Lucas',
#  'Rema',
#  'Sean Paul',
#  'Elaine',
#  'Lele Pons',
#  'Tavú',
#  'Latin Electronic Dance Music',
#  'Reykon',
#  'Monte',
#  'Jerry Di',
#  'Norwayy',
#  'Natalia Lugo',
#  'Almas Band',
#  'Kefas',
#  'Kran',
#  'Maná',
#  'Rando',
#  'Maria McCausland',
#  'Shonny',
#  'Jr Loppez',
#  'Boundary',
#  'Monitor Collective',
#  'Dunkelwald',
#  'Ragazzi',
#  'La Cantina',
#  'Besos',
#  'MOÜGLI',
#  'Mickey Destro',
#  'LoCura',
#  'Valentina',
#  'Latin Masters',
#  'Ñejo & Dalmata',
#  'The Marías',
#  'Un Final Fatal',
#  'The Romy',
#  'Sisah',
#  'Álvaro De Luna',
#  'Llane',
#  'RICO',
#  'Deuce Eclipse',
#  'Jake Williams',
#  'Lola Pistola',
#  'Kings of Salsa',
#  'Elegante & La Imperial',
#  'Marshmello',
#  'HUMBE',
#  'Alvaro Diaz',
#  'Ela Minus',
#  'Goth Babe',
#  'Elsa y Elmar',
#  'Gizmo Varillas',
#  'Brytiago',
#  'Chromeo',
#  'Miami Horror123',
#  'Calva Louise',
#  'Twin Seas',
#  'FARIANA',
#  'La Doña',
#  'Mabe Fratti',
#  'Lido Pimienta',
#  'Klik & Frik',
#  'Ramona',
#  'Ximena Sariñana',
#  'Latin Song Music',
#  'Lenny Tavárez',
#  'Yin Yin',
#  'Hermes Croatto',
#  'Reyna Tropical',
#  'Salt Cathedral',
#  'Technicolor Fabrics',
#  'Nicola Cruz',
#  'Maria Becerra',
#  'La Lá',
#  'ALOISIO',
#  'Pahua',
#  'Zabuza',
#  'La Maquinaria Norteña',
#  'Justin Quiles',
#  'MaryOla',
#  'Paulo Londra',
#  'TOLEDO',
#  'Angel Heredia',
#  'Faye Meana',
#  'Gustavo Voz Perdida',
#  'Alan Gomez',
#  'Bobui',
#  'Kim Loaiza',
#  'Dragon',
#  'Sr. Langosta',
#  'MiriK',
#  'Beret',
#  'Migrant Motel',
#  'Barrio Lindo',
#  'Beach Clinic',
#  'Duck Fizz',
#  'KURAYÁ',
#  'Ela Taubert',
#  'Vaya Futuro',
#  'Will Kano',
#  'Dinner Time',
#  'Mexican Institute Of Sound',
#  'Lorelle Meets The Obsolete',
#  'La Perversa',
#  'Katrina',
#  'Calibre 50',
#  'Tan Cologne',
#  'Adriel Favela',
#  'Giorgio Siladi',
#  'Renee Goust',
#  'El Otro Polo',
#  'unÁnima',
#  'Regal86',
#  'Kaida',
#  'Nolune',
#  'Mementut',
#  'SCAIRAT',
#  'Nancy Sanchez',
#  'francia',
#  'The Lsdays',
#  'Gaston Lopez',
#  'Nhii',
#  'sailawway',
#  'Kenya Grace',
#  'Brray',
#  'Mexican Restaurant',
#  'Cheo',
#  'Maluma',
#  'Abraham Dorta',
#  'Jonna Torres',
#  'Dua Lipa',
#  'Café Tacvba',
#  'Espuelérico',
#  'Lao Ra',
#  'Christian Nodal',
#  'MPeach',
#  'Margaux Bret',
#  'Tokischa',
#  'Ságan',
#  'Sueco',
#  'Bhietxa',
#  'Illegal Nobility',
#  'Vic Contreras',
#  'Renn',
#  'Joey Montana',
#  'LIT killah',
#  'Hexagrams',
#  'Mala Cotton',
#  'Chika Di',
#  'Gye Poppin',
#  'Cloud Eleven',
#  'Gran Radio Riviera',
#  'Elisa Tokeshi',
#  'Natalia Lafourcade',
#  'Lotus Collective',
#  'Selma Oxor',
#  'Miky la Sensa',
#  'Shoeg',
#  'Omar Romero',
#  'Mon Laferte',
#  'D3ndron',
#  'Lasso',
#  'Jesse Baez',
#  'Jhay Cortez',
#  'Easy Easy',
#  'Marx Haübey',
#  'zzoilo',
#  'Micro TDH']

# %%
#Cantidad de artistas que tenemos en nuestra base de datos de Latino para los años 22 y 23

len(artistas_latino_total)
# Out:
# 340

# %%
# Verificar si la llamada a la API de Music_Brainz funciona correctamente solo con un artista de ejemplo. Es este caso va a ser el OZUNA

# Creamos nuestra URL con los paramentros necesarios para Ozuna y para generar un archivo formato Jason.

url = 'https://musicbrainz.org/ws/2/artist/?query=artist:ozuna&fmt=json'

# Crear una variable para hacer la llamada a esta URL y poner un print con el STATUS_CODE de la llamada para saber si funciona correctamente

llamada = requests.get(url)  
print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200

# %%
# Diccionario Ozuna para guardar los datos del archivo Jason

dic_ozuna = llamada.json()

# %%
dic_ozuna
# Out:
# {'created': '2024-10-16T14:41:01.461Z',
#  'count': 3,
#  'offset': 0,
#  'artists': [{'id': 'f2651b63-a44d-4d1d-ba64-d981d971ecd1',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 100,
#    'gender-id': '36d3d30a-839d-3eda-8cb3-29be4384e4a9',
#    'name': 'Ozuna',
#    'sort-name': 'Ozuna',
#    'gender': 'male',
#    'country': 'PR',
#    'area': {'id': '3906cf32-00a7-32df-93cc-4710c5f5a542',
#     'type': 'Country',
#     'type-id': '06dd0ae4-8c74-30bb-b43d-95dcedf961de',
#     'name': 'Puerto Rico',
#     'sort-name': 'Puerto Rico',
#     'life-span': {'ended': None}},
#    'begin-area': {'id': 'c3503bb7-f32d-4536-a1af-b2623f54ab4f',
#     'type': 'City',
#     'type-id': '6fd8f29a-3d0a-32fc-980d-ea697b69da78',
#     'name': 'San Juan',
#     'sort-name': 'San Juan',
#     'life-span': {'ended': None}},
#    'ipis': ['00733893316'],
#    'isnis': ['0000000467299609'],
#    'life-span': {'begin': '1992-03-13', 'ended': None},
#    'aliases': [{'sort-name': 'Ozuna Rosado, Juan Carlos',
#      'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf',
#      'name': 'Juan Carlos Ozuna Rosado',
#      'locale': None,
#      'type': 'Legal name',
#      'primary': None,
#      'begin-date': None,
#      'end-date': None}],
#    'tags': [{'count': 1, 'name': 'latin'},
#     {'count': 2, 'name': 'reggaeton'},
#     {'count': 1, 'name': 'latin urban'},
#     {'count': 1, 'name': 'latin trap'},
#     {'count': 1, 'name': 'trap latino'}]},
#   {'id': 'fd25fa9e-037d-4852-a9fb-2ea659019425',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 79,
#    'name': 'Sunny Ozuna',
#    'sort-name': 'Ozuna, Sunny',
#    'life-span': {'ended': None}},
#   {'id': 'c1fe9a8b-64a9-4d1d-b589-7370bad0e71d',
#    'type': 'Person',
#    'type-id': 'b6e035f4-3ce9-331c-97df-83397230b0df',
#    'score': 78,
#    'name': 'Bobby Ozuna',
#    'sort-name': 'Ozuna, Bobby',
#    'ipis': ['00342794447'],
#    'life-span': {'ended': None}}]}

# %%
# Bucle for para ir iterando todos los artistas unicos que tenemos en la lista de Latino 22/23 y hacer la llamada para cada uno de ellos


for cantante in artistas_latino_total:
    url_latino = (f'https://musicbrainz.org/ws/2/artist/?query=artist:{cantante}&fmt=json')
    llamada = requests.get(url_latino)  
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {llamada.status_code}")
# Out:
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 200
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
# La llamada a la API nos ha dado una respuesta de tipo: 503
