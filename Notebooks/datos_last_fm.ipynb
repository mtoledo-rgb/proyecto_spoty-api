# %%
import os 
from dotenv import load_dotenv #importamos .env para introducir ahí nuestras credenciales
import pandas as pd
import requests
import time

# %%
# Crear una función de llamada a la API de Music Brainz

def llamar_api_lastfm(url):

    # Encabezados con el token de acceso

    # Realizar una solicitud con el GET a la url proporcionada y almacenar la llamada en una "respuesta"
    time.sleep(1)
    respuesta = requests.get(url)
    
    # Imprime el código de estado de la respuesta.
    print(f"La llamada a la API nos ha dado una respuesta de tipo: {respuesta.status_code}")  
    
    if respuesta.status_code != 200:  # Comprueba si la respuesta no fue exitosa (código de estado distinto de 200).
        print(f"El motivo por el que la llamada falló es {respuesta.reason}") # Imprime la razón de la falla.
         
    else:
        return respuesta.json()  # Si la llamada fue exitosa, devuelve los datos de respuesta en formato JSON.

# %%
ak_fm =	'45275fffebb8865ea08402cc6c12a3f9'

# %% [markdown]
# 1. POP

# %%
artistas_pop_path = '../Data/dataframe_pop.csv'
df_pop_fm = pd.read_csv(artistas_pop_path,index_col=0)

datos_pop = {'artista':[],'listeners':[],'playcount':[],'biografia':[],'artistas_similares':[]}
contador = 0
for artista in df_pop_fm['artista']:
    url_fm = f'http://ws.audioscrobbler.com//2.0/?method=artist.getinfo&artist={artista}&api_key={ak_fm}&format=json'
    respuesta_fm = requests.get(url_fm)
    
    if respuesta_fm.status_code == 200:
        datos = respuesta_fm.json()
        datos_pop['artista'].append(datos['artist']['name'])
        datos_pop['listeners'].append(datos['artist']['stats']['listeners'])
        datos_pop['playcount'].append(datos['artist']['stats']['playcount'])
        datos_pop['biografia'].append(datos['artist']['bio']['summary'])
        lista_similares = []
        for nombre in datos['artist']['similar']['artist'][0:4]:
                lista_similares.append(nombre['name'])
        datos_pop['artistas_similares'].append(lista_similares)
               
              
    else:
        print(f'fallo {respuesta_fm.text}')
print(datos_pop)
# Out:
# {'artista': ['Noah Kahan', 'Djo', 'Sabrina Carpenter', 'SZA', 'd4vd', 'SZA', 'Josh Meloy', 'Noah Kahan', 'Harry Styles', 'Suki Waterhouse', 'Lil Durk', 'beabadoobee', 'SZA', 'Drake', 'Sabrina Carpenter', 'Noah Kahan', 'Jid', 'Lizzy McAlpine', 'Taylor Swift', 'SZA', 'David Guetta', 'Wyatt Flores', 'Billie Eilish', 'Noah Kahan', 'Ernest', 'LECADE', 'Drake', 'omar apollo', 'Lainey Wilson', 'Imagine Dragons', 'Meghan Trainor', 'Noah Kahan', 'Post Malone', 'Benson Boone', 'Tate McRae', 'OneRepublic', 'Taylor Swift', 'SZA', 'Lainey Wilson', 'Noah Kahan', 'Drake', 'The Weeknd', 'Cults', 'Sabrina Carpenter', 'JVKE', 'SZA', 'Noah Kahan', 'Chance Peña', 'SZA', 'Becky G', 'Conan Gray', 'Feid', 'Harry Styles', 'Taylor Swift', 'Imagine Dragons', 'Taylor Swift', 'Rema', 'Conan Gray', 'SZA', 'Taylor Swift', 'Hotel Ugly', 'Joji', 'Dhruv', 'Alok', 'Warren Zeiders', 'Drake', 'Chance Peña', 'Riley Green', 'Conan Gray', 'SZA', '
osalía', 'Tyler Hubbard', 'Mau y Ricky', 'Lainey Wilson', 'Vance Joy', 'sub urban', 'The Weeknd', 'Nayeon', 'beabadoobee', 'Charlie Puth', 'Jack Harlow', 'Danny Ocean', 'Lainey Wilson', 'SZA', 'Koe Wetzel', 'Genevieve Stokes', 'Rauw Alejandro', 'Harry Styles', 'Raye', 'Raye', 'Sebastian Yatra', 'Shaboozey', 'Ive', 'Feid', 'Sabrina Carpenter', 'Beyoncé', 'Drake', 'Beyoncé', 'Taylor Swift', 'Gucci Mane', 'SZA', 'MGK', 'BLACKPINK', 'Jeremih', 'Shawn Mendes', 'The Weeknd', 'Beyoncé', 'BLACKPINK', 'Becky G', 'Ethel Cain', 'charlieonnafriday', 'STRAY KIDS', 'Nessa Barrett', 'Alex Warren', 'SZA', 'The 1975', 'ENHYPEN', 'Paris Paloma', 'Ive', 'Corey Kent', 'SZA', 'SZA', 'SZA', 'Kid Cudi', 'Dylan Conrique', 'Beyoncé', 'Megan Moroney', 'Voilà', 'Girl In Red', 'Lil Durk', 'Harry Styles', 'Dra ...

# %%
file_path_pop = '../Data/data_pop_fm.csv'
dataframe_pop_fm = pd.DataFrame(datos_pop)
dataframe_pop_fm.to_csv(file_path_pop)

# %% [markdown]
# 2. ROCK

# %%
artistas_rock_path = '../Data/dataframe_rock.csv'
df_rock_fm = pd.read_csv(artistas_rock_path,index_col=0)
datos_rock = {'artista':[],'listeners':[],'playcount':[],'biografia':[],'artistas_similares':[]}

for artista in df_rock_fm['artista']:
    url_fm = f'http://ws.audioscrobbler.com//2.0/?method=artist.getinfo&artist={artista}&api_key={ak_fm}&format=json'
    respuesta_fm = requests.get(url_fm)
    try:
        #respuesta_fm.status_code == 200
        datos = respuesta_fm.json()
        datos_rock['artista'].append(datos['artist']['name'])
        datos_rock['listeners'].append(datos['artist']['stats']['listeners'])
        datos_rock['playcount'].append(datos['artist']['stats']['playcount'])
        datos_rock['biografia'].append(datos['artist']['bio']['summary'])
        lista_similares = []
        for nombre in datos['artist']['similar']['artist'][0:4]:
            lista_similares.append(nombre['name'])
        datos_rock['artistas_similares'].append(lista_similares)
    except:
        print(f'fallo {respuesta_fm.text}')
print(datos_rock)
# Out:
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# {'artista': ['Royel Otis', 'Imagine Dragons', 'Jon Pardi', 'Cole Swindell', 'OneRepublic', 'The 1975', 'Dylan Scott', 'Walker Hayes', 'Imagine Dragons', 'House of Pain', 'Dustin Lynch', 'Mother Mother', 'Jon Pardi', 'Tauren Wells', 'Thomas Rhett', 'Midrift', 'for KING ', 'Dylan Scott', 'Depeche Mode', 'Brantley Gilbert', 'Imagine Dragons', 'Big Thief', 'Ghost', 'SunKissed Lola', 'Josiah and the Bonnevilles', 'Dustin Lynch', 'We Came As Romans', 'Stick Figure', 'quannnic', 'TobyMac', 'Stick Figure', 'The Black Keys', 'WET LEG', 'Mitchell Tenpenny', 'Chris Tomlin', 'Vance Joy', 'Stick Figure', 'Papa Roach', 'The
 'Ghost', 'The Score', 'Alex G', 'Imagine Dragons', 'Kairikibear', 'Little Stranger', 'Father John Misty', 'Jerry Lee Lewis', 'Jimmie Allen', 'Quarters of Change', 'Luna Li', 'Dustin Lynch', 'Highly Suspect', 'Arctic Monkeys', 'Ryan Stevenson', 'Rammstein', 'Elvis Presley', 'Stick Figure', 'Jon Pardi', 'Petey', 'Dylan Scott', 'Phil Wickham', 'WET LEG', 'Polyphia', 'Portugal. The Man', 'The Bones of J.R. Jones', 'Phil Wickham', 'Royel Otis', 'Ben Rector', 'Drake White', 'Dustin Lynch', 'Rammstein', 'Nickelback', 'Florence   The Machine', 'Fontaines D.C.', 'Slipknot', 'Imagine Dragons', 'Fontaines D.C.', 'Brantley Gilbert', 'Palace', 'Alvvays', 'Three Days Grace', 'Vance Joy', 'Polyphia', 'Sam Hunt', 'Colorblind', 'Young the Giant', 'Ghost', 'The 1975', 'Casting Crowns', 'Nickelback', 'Arcy Drive', 'Arctic Monkeys', 'Thomas Rhett', 'Pacific Roots', 'Vance Joy', 'Glass Animals ...

# %%
file_path_rock = '../Data/data_rock_fm.csv'
dataframe_rock_fm = pd.DataFrame(datos_rock)
dataframe_rock_fm.to_csv(file_path_rock)

# %% [markdown]
# 3. HIP-HOP

# %%
artistas_hiphop_path = '../Data/dataframe_hiphop.csv'
df_hiphop_fm = pd.read_csv(artistas_hiphop_path,index_col=0)
datos_hiphop = {'artista':[],'listeners':[],'playcount':[],'biografia':[],'artistas_similares':[]}

for artista in df_hiphop_fm['Artista']:
    url_fm = f'http://ws.audioscrobbler.com//2.0/?method=artist.getinfo&artist={artista}&api_key={ak_fm}&format=json'
    respuesta_fm = requests.get(url_fm)
    try:
        #respuesta_fm.status_code == 200
        datos = respuesta_fm.json()
        datos_hiphop['artista'].append(datos['artist']['name'])
        datos_hiphop['listeners'].append(datos['artist']['stats']['listeners'])
        datos_hiphop['playcount'].append(datos['artist']['stats']['playcount'])
        datos_hiphop['biografia'].append(datos['artist']['bio']['summary'])
        lista_similares = []
        for nombre in datos['artist']['similar']['artist'][0:4]:
            lista_similares.append(nombre['name'])
        datos_hiphop['artistas_similares'].append(lista_similares)
    except:
        print(f'fallo {respuesta_fm.text}')
print(datos_hiphop)
# Out:
# fallo <?xml version="1.0" encoding="UTF-8"?>
# <lfm status="failed">
#   <error code="6">Invalid parameters - Your request is missing a required parameter</error>
# </lfm>
#
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo <?xml version="1.0" encoding="UTF-8"?>
# <lfm status="failed">
#   <error code="6">Invalid parameters - Your request is missing a required parameter</error>
# </lfm>
#
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# {'artista': ['Jean Dawson', 'Caye', 'DaBaby', 'Gucci Mane', 'JZAC', 'Bazanji', 'Shordie Shordie', 'Token', 'Token', 'Campel', 'Common', 'A BOOGIE WIT DA HOODIE', 'Blu', 'N2DEEP', 'Common', 'K.A.A.N.', 'Justin Stone', 'Logic', 'K.A.A.N.', 'Ka', 'DJ Feedo', 'Ka', 'Kid Cudi', 'K.A
o', 'NLE Choppa', 'Don Toliver', 'Jrocka', 'Gucci Mane', 'Young Thug', 'Black Rob', 'Sm!les', 'Knox Hill', 'Gang Starr', 'Cardi B', 'Group Home', 'Iggy Azalea', 'The Notorious B.I.G.', 'LIL UZI VERT', '112', 'Saweetie', 'R R=NOW', 'Christ Hip Hop', 'DJ Feedo', 'Rae Sremmurd', '2 Chainz', 'Gazelle Hunter', 'Pop Smoke', 'Urbanlegends', 'JZAC', 'Nicki Minaj', 'Jack Harlow', 'Tee Marsh', 'Joey Cool', 'Da Endless', 'Rap Caviar', 'Jack Harlow', 'Global Don', 'Jack Harlow', 'DaBaby', 'Choi Seong', 'Raphael Lake', 'HipHop Playlist', 'SMALL D', 'Kyle Sutton', 'Boldy James', 'Juice WRLD', 'Juice WRLD', 'Diddy', 'Lor_Kreny', 'Jack Harlow', 'Mustard', 'Tee Grizzley', 'Pop Smoke', 'DaBaby', 'Urbanlegends', 'Gucci Mane', 'Juice WRLD', 'Jack Harlow', 'Tee Grizzley', 'Cardi B', 'Kodak Black', 'A2', 'Jigmastas', 'Leschea', 'Fastmoney Ant', 'Joey Cool', 'Mustard', 'Gucci Mane', 'Parker', 'Acclimate Hip Hop', 'B.o.B', 'o2worldwide', 'Logic', 'Tee Grizzley', 'Blu', 'DaBaby', 'Lental', 'A BOOGIE WIT DA HOODIE', 'Culture Clan', 'NLE Choppa', 'Mac Miller', 'Lil Baby', 'Gucci Mane', 'Blu', 'Zero14', 'Upgrade HipHop', 'Kodak Black', 'Todays Top Hits', 'Smooth Hiphop Cafe', 'Sonny Digital', 'Saweetie', 'Toylah', 'Quavo', 'Migos', 'Megan Thee Stallion', 'Year of the Ox', 'LIL UZI VERT', 'Roddy Ricch', '2022 Hit Songs Music Mix', 'NLE Choppa', 'Gucci Mane', 'Hip Hop For The World', '2022 Hit Songs Music Mix', 'Naughty By Nature', 'NLE Choppa', 'Quavo', 'Turbo', 'Mike Shinoda', 'Roddy Ricch', 'Cardi B', 'Top 40 Hip-Hop Hits', 'Parker', 'Armani White', 'K.A.A.N.', 'A BOOGIE WIT DA HOODIE', 'Khafre Ja ...

# %%
file_path_hiphop = '../Data/data_hiphop_fm.csv'
dataframe_hiphop_fm = pd.DataFrame(datos_hiphop)
dataframe_hiphop_fm.to_csv(file_path_hiphop)

# %% [markdown]
# 4. LATINO

# %%
artistas_latino_path = '../Data/dataframe_latino.csv'
df_latino_fm = pd.read_csv(artistas_latino_path,index_col=0)
datos_latino = {'artista':[],'listeners':[],'playcount':[],'biografia':[],'artistas_similares':[]}
for artista in df_latino_fm['Artista']:
    url_fm = f'http://ws.audioscrobbler.com//2.0/?method=artist.getinfo&artist={artista}&api_key={ak_fm}&format=json'
    respuesta_fm = requests.get(url_fm)
    try:
        #respuesta_fm.status_code == 200
        datos = respuesta_fm.json()
        datos_latino['artista'].append(datos['artist']['name'])
        datos_latino['listeners'].append(datos['artist']['stats']['listeners'])
        datos_latino['playcount'].append(datos['artist']['stats']['playcount'])
        datos_latino['biografia'].append(datos['artist']['bio']['summary'])
        lista_similares = []
        for nombre in datos['artist']['similar']['artist'][0:4]:
            lista_similares.append(nombre['name'])
        datos_latino['artistas_similares'].append(lista_similares)
    except:
        print(f'fallo {respuesta_fm.text}')
print(datos_latino)
# Out:
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
# fallo {"error":6,"message":"The artist you supplied could not be found","links":[]}
man', 'Polaris', 'Tayko', 'Mint Field', 'Milos', 'Milos', 'Rubytates', 'Seba Otero', 'Cabra', 'Mitú', 'Mitú', 'ÌFÉ', 'Gina Chavez', 'Jarina De Marco', 'Ley Vara', 'Puya', 'Nikola', 'Adri Torron', 'Ratas', 'JAVVI ELIAS', 'ÌFÉ', 'Mitú', 'Balún', 'ÌFÉ', 'Tayko', 'Dogos', 'ÌFÉ', 'Cabra', 'B-Side Players', 'Polbo', 'La Dame Blanche', 'Words Four Two', 'Sofía Stainer', 'Qiensave', 'Mitú', 'Ozomatli', 'El Hijo de Borikén', 'Laura Guevara', 'Von Galo', 'Polaris', 'Red Tiger', 'LA R', 'Gina Chavez', 'Mint Field', 'Ocho Ojos', 'Mitú', 'Prettiest Eyes', 'Fofé y Los Fetiches', 'ÌFÉ', 'Marc Seguí', 'Mitú', 'Piso 21', 'Onda Moderna', 'Paraísos', 'J Balvin', 'Labajura', 'ÌFÉ', 'Breezewood la Connecta', 'Onda Moderna', 'TIMØ', 'Campo-Formio', 'B-Side Players', 'LA R', 'Chris Jedi', 'Tainy', 'Karol G', 'Balún', 'Blessd', 'Alex Sensation', 'Danny Ocean', 'Labajura', 'Indigo', 'Feid', 'LA R', 'Danny Ocean', 'The Spam Allstars', 'La Mejor Música Electrónica', 'Karol G', 'B-Side Players', 'Polbo', 'Boricua Boys', 'BANG DATa', 'Sebastian Yatra', 'Omaraga the G', 'J Balvin', 'Qiensave', 'Sebastian Yatra', 'Ratas', 'Un.Real', 'The Flashers Brothers', 'J Balvin', 'Jhayco', 'Milos', 'Qiensave', 'J Balvin', 'Campo-Formio', 'B-Side Players', 'Mima', 'Onda Moderna', 'Zion ', 'Balún', 'J Balvin', 'NY Latino Chillout Café', 'Balún', 'Dogos', 'Danny Ocean', 'Karol G', 'Nacho', 'tropiezo', 'Lú Polanco', 'Michelle', 'Karol G', 'Como Las Movies', 'LA R', 'Omaraga the G', 'La Muchacha', 'Former Astronauts', 'SLVG', 'Yibáro', 'Feid', 'J Balvin', 'ÌFÉ', 'Poolpo', 'Mitú', 'Kumbia Queers', 'Balún', 'Nacho', 'Milos', 'Balún', 'Red Tiger', 'Spam Allstars', 'Cabas', 'J Balvin', 'Turista', 'ÌFÉ', 'Balún', 'Balún', 'Feid', 'Red Tiger', 'Danny Ocean', 'LA R', 'Red Tiger', 'Campo-Formio', 'Red Tiger', 'Campo-Formio', 'Moncho Berry', 'Words Four Two', 'J Balvin', 'TROPA', 'Turista', 'Musica Latina', 'Salsaloco De Cuba', 'Feid', 'La Mejor Música Electrónica', 'Balún', 'Sano', 'bad gyal', 'Bosques', 'Badshah', 'Marc Seguí', 'Danny Ocean', 'Nicole Zignago', 'Luis Fonsi', 'Yibáro', 'Mitú', 'La Mejor Música Electrónica', 'Se ...

# %%
file_path_latino = '../Data/data_latino_fm.csv'
dataframe_latino_fm = pd.DataFrame(datos_latino)
dataframe_latino_fm.to_csv(file_path_latino)
